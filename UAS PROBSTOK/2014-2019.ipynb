# %%
import quandl
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as pdr
import datetime

# %%
start = datetime.datetime(2014,1,1)
end = datetime.datetime(2019,12,1)
#set waktu awal dan akhir untuk tanggal saham

# %%
df1 = pdr.DataReader('WIKA.JK', 'yahoo', start, end)
df2 = pdr.DataReader('PTPP.JK', 'yahoo', start, end)
df3 = pdr.DataReader('ADHI.JK', 'yahoo', start, end)
df4= pdr.DataReader('WSKT.JK', 'yahoo', start, end)
#import data dari yahoo sesuai dengan kode sahamnya

# %%
df1.tail()
# Out:
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2019-11-26  1960.0  1915.0  1935.0  1960.0  10418600.0     1960.0
# 2019-11-27  1960.0  1835.0  1960.0  1870.0  14740700.0     1870.0
# 2019-11-28  1875.0  1785.0  1870.0  1790.0  12844100.0     1790.0
# 2019-11-29  1790.0  1710.0  1790.0  1735.0  25019200.0     1735.0
# 2019-12-02  1815.0  1720.0  1740.0  1800.0  27221900.0     1800.0

# %%
df2.tail()
# Out:
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2019-11-26  1535.0  1490.0  1510.0  1505.0  12359900.0     1505.0
# 2019-11-27  1505.0  1440.0  1495.0  1440.0  15222000.0     1440.0
# 2019-11-28  1460.0  1375.0  1460.0  1385.0  21863500.0     1385.0
# 2019-11-29  1385.0  1340.0  1375.0  1350.0  18143700.0     1350.0
# 2019-12-02  1425.0  1345.0  1370.0  1405.0  30174600.0     1405.0

# %%
df3.tail()
# Out:
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2019-11-26  1195.0  1160.0  1190.0  1180.0   4059800.0     1180.0
# 2019-11-27  1190.0  1135.0  1180.0  1135.0  10291100.0     1135.0
# 2019-11-28  1150.0  1100.0  1135.0  1100.0   5888600.0     1100.0
# 2019-11-29  1110.0  1060.0  1105.0  1075.0   8548400.0     1075.0
# 2019-12-02  1115.0  1080.0  1085.0  1110.0   9646800.0     1110.0

# %%
df4.tail()
# Out:
#               High     Low    Open   Close      Volume  Adj Close
# Date
# 2019-11-26  1385.0  1355.0  1385.0  1370.0  17633200.0     1370.0
# 2019-11-27  1370.0  1300.0  1370.0  1305.0  18362500.0     1305.0
# 2019-11-28  1325.0  1275.0  1305.0  1285.0  16306300.0     1285.0
# 2019-11-29  1285.0  1215.0  1280.0  1225.0  39429500.0     1225.0
# 2019-12-02  1280.0  1225.0  1225.0  1275.0  32747200.0     1275.0

# %%
adj_close1 = df1['Adj Close']
adj_close2 = df2['Adj Close']
adj_close3 = df3['Adj Close']
adj_close4 = df4['Adj Close']
#membuat variabel untuk bagian 'close' saja

# %%
time1 = np.linspace(1, len(adj_close1), len(adj_close1))
time2 = np.linspace(1, len(adj_close2), len(adj_close2))
time3 = np.linspace(1, len(adj_close3), len(adj_close3))
time4 = np.linspace(1, len(adj_close4), len(adj_close4))
#membuat variabel waktu

# %%
plt.plot(time1, adj_close1, label = 'WIKA', ls = '--')
plt.plot(time2, adj_close2, label = 'PTPP', ls = '--')
plt.plot(time3, adj_close3, label = 'ADHI', ls = '--')
plt.plot(time4, adj_close4, label = 'WSKT', ls = '--')
plt.legend(loc = 'upper right')
#menampilkan grafik data saham

# %%
pylab.rcParams['figure.figsize'] = (15, 9)   
 
df1['Adj Close'].plot(grid = True,label='WIKA') 
df2['Adj Close'].plot(grid = True, label='PTPP')
df3['Adj Close'].plot(grid = True, label='ADHI')
df4['Adj Close'].plot(grid = True, label='WSKT')
pylab.legend(loc = 'upper right')
#menampilkan grafik data saham

# %%
start = datetime.datetime(2019,9,1)
end = datetime.datetime(2019,12,1)

# %%
da1 = pdr.DataReader('WIKA.JK', 'yahoo', start, end)
da2 = pdr.DataReader('PTPP.JK', 'yahoo', start, end)
da3 = pdr.DataReader('ADHI.JK', 'yahoo', start, end)
da4= pdr.DataReader('WSKT.JK', 'yahoo', start, end)

# %%
pylab.rcParams['figure.figsize'] = (15, 9)   
 
da1['Adj Close'].plot(grid = True,label='WIKA') 
da2['Adj Close'].plot(grid = True, label='PTPP')
da3['Adj Close'].plot(grid = True, label='ADHI')
da4['Adj Close'].plot(grid = True, label='WSKT')
pylab.legend(loc = 'upper right')
#menampilkan grafik dengan tanggal yang diminta

# %%
start = datetime.datetime(2019,7,1)
end = datetime.datetime(2019,11,1)

# %%
ds1 = pdr.DataReader('WIKA.JK', 'yahoo', start, end)
ds2 = pdr.DataReader('PTPP.JK', 'yahoo', start, end)
ds3 = pdr.DataReader('ADHI.JK', 'yahoo', start, end)
ds4= pdr.DataReader('WSKT.JK', 'yahoo', start, end)

# %%
pylab.rcParams['figure.figsize'] = (15, 9)   
 
ds1['Adj Close'].plot(grid = True,label='WIKA') 
ds2['Adj Close'].plot(grid = True, label='PTPP')
ds3['Adj Close'].plot(grid = True, label='ADHI')
ds4['Adj Close'].plot(grid = True, label='WSKT')
pylab.legend(loc = 'upper right')
#menampilkan grafik dengan tanggal yang diminta

# %%
start = datetime.datetime(2019,1,1)
end = datetime.datetime(2019,12,31)

# %%
da1 = pdr.DataReader('WIKA.JK', 'yahoo', start, end)
da2 = pdr.DataReader('PTPP.JK', 'yahoo', start, end)
da3 = pdr.DataReader('ADHI.JK', 'yahoo', start, end)
da4= pdr.DataReader('WSKT.JK', 'yahoo', start, end)

# %%
adj_closeA = da1['Adj Close']
adj_closeB = da2['Adj Close']
adj_closeC = da3['Adj Close']
adj_closeD = da4['Adj Close']

# %%
timeA = np.linspace(1, len(adj_closeA), len(adj_closeA))
timeB = np.linspace(1, len(adj_closeB), len(adj_closeB))
timeC = np.linspace(1, len(adj_closeC), len(adj_closeC))
timeD = np.linspace(1, len(adj_closeD), len(adj_closeD))

# %%
def daily_return(adj_close):
    returns = []
    for i in range(0, len(adj_close)-1):
        today = adj_close[i+1]
        yesterday = adj_close[i]
        daily_return = (today - yesterday)/yesterday
        returns.append(daily_return)
    return returns

returns1 = daily_return(adj_closeA)
returns2 = daily_return(adj_closeB)
returns3 = daily_return(adj_closeC)
returns4 = daily_return(adj_closeD)

mu1 = np.mean(returns1)*252           
sig1 = np.std(returns1)*np.sqrt(252.) 

mu2 = np.mean(returns2)*252           
sig2 = np.std(returns2)*np.sqrt(252.) 

mu3 = np.mean(returns3)*252           
sig3 = np.std(returns3)*np.sqrt(252.) 

mu4 = np.mean(returns4)*252           
sig4 = np.std(returns4)*np.sqrt(252.) 
#perhitungan GBM-nya

# %%
print(mu1, sig1)
print(mu2, sig2)
print(mu3, sig3)
print(mu4, sig4)
# Out:
# 0.31664310823641956 0.39779736788832876
# 0.019230526819764657 0.41809542949744866
# -0.1849091779826319 0.3170502687428641
# -0.044547211851235266 0.36271601386647234

# %%
#GBM Exact Solution
#parameter
#so     : initial stock price
#mu     : koef. drift
#sig    : koef. diff.
#W      : brown motion
#T      : Time Period
#N      : number of increment

# %%
#menampilkan grafik prediksinya

def GBM(so, mu, sig, W, T, N):
    t = np.linspace(0., 1., N+1)
    s = []
    s.append(so)
    for i in range(1, int(N+1)):
        drift = (mu - 0.5*sig**2)*t[i]
        diffusion = sig1*W[i-1]
        s_temp = so*np.exp(drift+diffusion)
        s.append(s_temp)
    return s, t
T= 1.
N = 2.**6

seed = 1
W = brownian(seed, N)[0]
so1 = adj_close1[0] #intial value stock price
sol1 = GBM(so1, mu1, sig1, W, T, N)[0]  #exact solution
t1 = GBM(so1, mu1, sig1, W, T, N)[1]    #time increments for plotting

seed = 2
W = brownian(seed, N)[0]
so2 = adj_close2[0] #intial value stock price
sol2 = GBM(so2, mu2, sig2, W, T, N)[0]  #exact solution
t2 = GBM(so2, mu2, sig2, W, T, N)[1]    #time increments for plotting

seed = 3
W = brownian(seed, N)[0]
so3 = adj_close3[0] #intial value stock price
sol3 = GBM(so3, mu3, sig3, W, T, N)[0]  #exact solution
t3 = GBM(so3, mu3, sig3, W, T, N)[1]    #time increments for plotting

seed = 4
W = brownian(seed, N)[0]
so4 = adj_close1[0] #intial value stock price
sol4 = GBM(so4, mu4, sig4, W, T, N)[0]  #exact solution
t4 = GBM(so4, mu4, sig4, W, T, N)[1]    #time increments for plotting

plt.plot( t1,sol1, label = 'WIKA', ls = '--')
plt.plot( t2,sol2, label = 'PTPP', ls = '--')
plt.plot( t3,sol3, label = 'ADHI', ls = '--')
plt.plot( t4,sol4, label = 'WSKT', ls = '--')

plt.ylabel('WIKA,PTPP,WKST,ADHI (dalam Rupiah)')
plt.title('Geometric Brownian Motion - WIKA, PTPP, WSKT, ADHI')
plt.legend(loc = 'upper left')
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
